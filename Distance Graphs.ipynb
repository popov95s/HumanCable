# %%
Baud = [9600, 38400, 57600, 115200, 230400, 460800, 345600, 403200, 432000, 446400, 439200, 442800]
Matches = [139, 139, 139, 139, 139, 0, 139, 139, 129, 0, 133, 0]
Distance = [0, 0, 0, 0, 0, 50000, 0, 0, 13, 50000, 14, 50000]

# %%
import matplotlib.pyplot as plt
x = Baud
y = Matches
plt.scatter(x, y)
plt.title('Average Number of Correct Sequences vs Baudrate')
plt.xlabel('Baudrate')
plt.ylabel('Correct sequences')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ee69a6815956> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 x = Baud
#       3 y = Matches
#       4 plt.scatter(x, y)
#       5 plt.title('Average Number of Correct Sequences vs Baudrate')
#
# NameError: name 'Baud' is not defined

# %%
y = Distance
plt.scatter(x, y)
plt.title('Average Levenshtein distance vs Baudrate')
plt.xlabel('Baudrate')
plt.ylabel('Distance')
plt.show()

# %%
x = [9600, 38400, 57600, 115200, 230400, 460800]
y = [139, 139, 139, 139, 138, 0]
plt.scatter(x,y)
plt.title('Average Number of Correct Sequences vs Baudrate for Finger to Finger')
plt.xlabel('Baudrate')
plt.ylabel('Correct sequences')
plt.show()

# %%
y = [0, 0, 0, 0, 1.666666667, 50000]
plt.scatter(x,y)
plt.title('Average Levenshtein Distance vs Baudrate for Finger to Finger')
plt.xlabel('Baudrate')
plt.ylabel('Distance')
plt.show()

# %%
y = [138.6666667, 104.3333333, 135, 139, 136.6666667, 0]
plt.scatter(x,y)
plt.title('Average Number of Correct Sequences vs Baudrate for Wrist to Door')
plt.xlabel('Baudrate')
plt.ylabel('Correct Sequences')
plt.show()

# %%
y = [0.3333333333, 7321, 15.66666667, 0, 5.333333333, 50000]
plt.scatter(x,y)
plt.title('Average Levenshtein Distance vs Baudrate for Wrist to Door')
plt.xlabel('Baudrate')
plt.ylabel('Distance')
plt.show()

# %%
y = [138
,139
,139
,138.6666667
,138.6666667
,0]
plt.scatter(x,y)
plt.title('Average Number of Correct Sequences vs Baudrate for Wrist to Finger')
plt.xlabel('Baudrate')
plt.ylabel('Correct Sequences')
plt.show()

# %%
y = [1.333333333
,0
,0
,0.3333333333
,0.3333333333
,50000]
plt.scatter(x,y)
plt.title('Average Levenshtein Distance vs Baudrate for Wrist to Finger')
plt.xlabel('Baudrate')
plt.ylabel('Distance')
plt.show()

# %%
y = [137
,137.3333333
,127.6666667
,139
,138
,0]
plt.scatter(x,y)
plt.title('Average Number of Correct Sequences vs Baudrate for Wrist to Wrist')
plt.xlabel('Baudrate')
plt.ylabel('Correct Sequences')
plt.show()

# %%
y = [26.33333333
,30
,19.66666667
,0
,3
,50000]
plt.scatter(x,y)
plt.title('Average Levenshtein Distance vs Baudrate for Wrist to Wrist')
plt.xlabel('Baudrate')
plt.ylabel('Distance')
plt.show()

# %%
labels = ['Wire', 'Finger to Finger', 'Wrist to Finger',  'Wrist to Door', 'Wrist to Wrist']
x = [1,2,3,4,5]
y = [126.8152584 ,122.0882826 ,125.7524375 ,122.5792965 ,115.7135734]
plt.bar(x,y)
plt.xticks(x, labels, rotation='vertical')
plt.title('SD of analog values at 5700 Baudrate')
plt.xlabel('Scenarios')
plt.ylabel('Analog Value SD')
plt.show()

# %%
labels = ['Wire', 'Finger to Finger', 'Wrist to Finger',  'Wrist to Door', 'Wrist to Wrist']
x = [1,2,3,4,5]
y = [0 ,175.5454545 ,126.7272727 ,284.4090909 ,1583.090909]
plt.bar(x,y)
plt.xticks(x, labels, rotation='vertical')
plt.title('Resistances of Scenarios')
plt.xlabel('Scenarios')
plt.ylabel('Resistance (kOhms)')
plt.show()
